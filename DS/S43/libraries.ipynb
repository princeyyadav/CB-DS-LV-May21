# %%
from keras.layers import Dense
from keras.models import Sequential
from keras.activations import sigmoid
from keras.losses import binary_crossentropy, categorical_crossentropy
# from keras.optimizer_v1 import SGD
from tensorflow.keras.optimizers import SGD

# %%
model = Sequential()
model.add(Dense(units=3, activation='sigmoid', input_shape=(2,)))
model.add(Dense(units=2, activation='sigmoid'))
model.add(Dense(units=1, activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_24 (Dense)             (None, 3)                 9
# _________________________________________________________________
# dense_25 (Dense)             (None, 2)                 8
# _________________________________________________________________
# dense_26 (Dense)             (None, 1)                 3
# ...
# Total params: 20
# Trainable params: 20
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Data Generation

# %%
from sklearn.datasets import make_gaussian_quantiles
import matplotlib.pyplot as plt

# %%
X, y = make_gaussian_quantiles(n_samples=500, n_features=2, n_classes=2)
print(X.shape, y.shape)
# Out:
# (500, 2) (500,)

# %%
plt.scatter(X[:,0], X[:,1], c=y)
plt.show()

# %%
model.compile(optimizer=SGD(learning_rate=1), loss='binary_crossentropy', metrics='accuracy')
model.fit(X,y, epochs=2000, batch_size=500)
# Out:
# Epoch 1/2000
# 1/1 [==============================] - 1s 594ms/step - loss: 0.8140 - accuracy: 0.5000
# Epoch 2/2000
# 1/1 [==============================] - 0s 24ms/step - loss: 0.7352 - accuracy: 0.5000
# Epoch 3/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.7073 - accuracy: 0.5000
# Epoch 4/2000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6979 - accuracy: 0.5000
# Epoch 5/2000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6948 - accuracy: 0.5000
# Epoch 6/2000
# 1/1 [==============================] - 0s 25ms/step - loss: 0.6937 - accuracy: 0.4460
# Epoch 7/2000
# 1/1 [==============================] - 0s 17ms/step - loss: 0.6933 - accuracy: 0.3520
# Epoch 8/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6932 - accuracy: 0.3980
# Epoch 9/2000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6931 - accuracy: 0.4700
# Epoch 10/2000
# ...

# %%
model2 = Model(inputs = model.input, outputs=model.get_layer("dense_25").output)
X2 = model2.predict(X)
print(X2.shape)
# Out:
# (500, 2)

# %%
plt.scatter(X2[:,1], X2[:,0], c=y)
plt.show()

# %%
model = Sequential()
model.add(Dense(units=3, activation='relu', input_shape=(2,)))
model.add(Dense(units=2, activation='relu'))
model.add(Dense(units=1, activation='sigmoid'))

# %%
model.compile(optimizer=SGD(learning_rate=0.1), loss='binary_crossentropy', metrics='accuracy')
model.fit(X,y, epochs=500, batch_size=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 1s 620ms/step - loss: 0.6568 - accuracy: 0.5620
# Epoch 2/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6561 - accuracy: 0.5620
# Epoch 3/500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.6554 - accuracy: 0.5620
# Epoch 4/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.6548 - accuracy: 0.5660
# Epoch 5/500
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6541 - accuracy: 0.5680
# Epoch 6/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6534 - accuracy: 0.5720
# Epoch 7/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6528 - accuracy: 0.5760
# Epoch 8/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6521 - accuracy: 0.5780
# Epoch 9/500
# 1/1 [==============================] - 0s 22ms/step - loss: 0.6515 - accuracy: 0.5800
# Epoch 10/500
# ...

# %%
model.evaluate(X,y)
# Out:
# 16/16 [==============================] - 1s 2ms/step - loss: 0.1474 - accuracy: 0.9640
# [0.14739443361759186, 0.9639999866485596]

# %%
model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_21 (Dense)             (None, 3)                 9
# _________________________________________________________________
# dense_22 (Dense)             (None, 2)                 8
# _________________________________________________________________
# dense_23 (Dense)             (None, 1)                 3
# ...
# Total params: 20
# Trainable params: 20
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.models import Model

# %%
model1 = Model(inputs = model.input, outputs=model.get_layer("dense_22").output)

# %%
X1 = model1.predict(X)

# %%
print(X1.shape)
# Out:
# (500, 2)

# %%
plt.scatter(X1[:,0], X1[:,1], c=y)
plt.show()
